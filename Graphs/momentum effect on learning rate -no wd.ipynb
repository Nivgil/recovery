# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> CIFAR10 Momentum Effect on Training - No Weight Decay</h1>
# <h2 style="text-align: center;" markdown="1"> WideResnet 28-2 </h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
sim_num = [402, 401]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h3>Simulation {0}: Min Error - {1:.2f}% , Val Error - {2:.2f}% , Mean Error - {3:.2f}%<h3>'.format(sim[0],sim[1][0],sim[1][1],sim[1][2])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="c23a59dc-95b5-42a5-90c8-82d9925bf737">Loading BokehJS ...</span>
#     </div>
# <h3>Simulation 402: Min Error - 6.66% , Val Error - 6.73% , Mean Error - 6.73%<h3>
# <h3>Simulation 401: Min Error - 7.05% , Val Error - 7.17% , Mean Error - 7.18%<h3>

# %%
print('legend - (batchsize, #workers, momentum, dampening, lr)')
show(plots[1])
# Out:
# legend - (batchsize, #workers, momentum, dampening, lr)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f9509d5b-ef8f-40a2-afe0-23b27f1ac314"></div>
# </div>

# %%
print('legend - (batchsize, #workers, momentum, dampening, lr)')
show(plots[0])
# Out:
# legend - (batchsize, #workers, momentum, dampening, lr)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="756c5069-cc9f-450b-9d8c-76a5bb132f0b"></div>
# </div>

# %%
print('legend - (batchsize, #workers, momentum, dampening, lr)')
show(plots[2])
# Out:
# legend - (batchsize, #workers, momentum, dampening, lr)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="307edf94-65d1-48d6-9616-a8d4afb0e1d1"></div>
# </div>

# %%
print('legend - (batchsize, #workers, momentum, dampening, lr)')
show(plots[3])
# Out:
# legend - (batchsize, #workers, momentum, dampening, lr)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="ce014daa-d196-4897-b93a-94b02bf46710"></div>
# </div>

# %%
print('legend - (batchsize, #workers, momentum, dampening, lr)')
show(plots[4])
# Out:
# legend - (batchsize, #workers, momentum, dampening, lr)
# <div class="bk-root">
#     <div class="bk-plotdiv" id="24b09f92-2818-466c-9728-715fe64d42e3"></div>
# </div>
