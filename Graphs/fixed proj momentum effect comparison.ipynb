# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> CIFAR10 - Momentum, Norm & Last Hidden Layer</h1>
# <h2 style="text-align: center;" markdown="1"> WideResnet - 28 - 10</h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
import warnings
warnings.filterwarnings('ignore')
sim_num = [378, 377, 315, 307]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h6> #Simulation {:1d} - Min Error {:.2f}% , Mean Error {:.2f}% , Val Error {:.2f}%<h6>'.format(sim[0],sim[1][0],sim[1][1],sim[1][2])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="90b9b6fa-3a49-41ac-ac5d-bf7ecb6e97ad">Loading BokehJS ...</span>
#     </div>
# <h6> #Simulation 378 - Min Error 3.78% , Mean Error 3.88% , Val Error 3.88%<h6>
# <h6> #Simulation 377 - Min Error 3.81% , Mean Error 3.93% , Val Error 3.90%<h6>
# <h6> #Simulation 315 - Min Error 3.68% , Mean Error 3.78% , Val Error 3.75%<h6>
# <h6> #Simulation 307 - Min Error 3.91% , Mean Error 4.00% , Val Error 4.01%<h6>

# %%
print('Legend - (batchsize, #w, momentum, dampening, lr, #sim)')
print('378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[1])
# Out:
# Legend - (batchsize, #w, momentum, dampening, lr, #sim)
# 378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="c2227422-a7fd-4ea1-ba39-b6e8c1deeb98"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="7f61e799-b04c-4230-9799-a34b8c9a97cc"></div>
# </div>

# %%
print('378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[2])
# Out:
# 378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="fea1314f-756a-4ab1-a624-f847db27a8b3"></div>
# </div>

# %%
print('378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[3])
# Out:
# 378 - Momentum Fixed Proj, 377 - No Momentum Fixed Proj, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="d061793d-3499-4f76-b416-9ed45798f8cf"></div>
# </div>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Niv Giladi - Technion
# </footer>
