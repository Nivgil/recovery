# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> ImageNet - Asynchronous 32 workers momentum effect</h1>
# <h2 style="text-align: center;" markdown="1"> Resnet 50</h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
sim_num = [160, 184, 427, 2131]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h6> #Simulation {:1d} - Min Error {:.2f}% , Mean Error {:.2f}%<h6>'.format(sim[0],sim[1][0],sim[1][1])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ab97268d-a2de-413b-ada8-a51c5bf14718">Loading BokehJS ...</span>
#     </div>
# <h6> #Simulation 160 - Min Error 23.69% , Mean Error 23.96%<h6>
# <h6> #Simulation 184 - Min Error 26.41% , Mean Error 26.54%<h6>
# <h6> #Simulation 427 - Min Error 27.21% , Mean Error 27.41%<h6>
# <h6> #Simulation 2131 - Min Error 27.28% , Mean Error 27.37%<h6>

# %%
show(plots[1])
# Out:
# C:\Users\giladiniv\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# <div class="bk-root">
#     <div class="bk-plotdiv" id="cba070ae-aff7-4a46-9c65-d1820c5cd5b8"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="b20ae0ed-c98f-4704-9692-dd724b2f6ebc"></div>
# </div>

# %%
show(plots[2])
# Out:
# C:\Users\giladiniv\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# <div class="bk-root">
#     <div class="bk-plotdiv" id="85e60579-e8e1-4d35-989c-215df9b090ad"></div>
# </div>

# %%
show(plots[3])
# Out:
# C:\Users\giladiniv\AppData\Local\Continuum\anaconda3\lib\site-packages\bokeh\core\json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# <div class="bk-root">
#     <div class="bk-plotdiv" id="61eb03f5-eb1c-4f3b-b29e-ee1318c33704"></div>
# </div>
