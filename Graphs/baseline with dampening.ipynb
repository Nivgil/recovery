# %% [raw]
# <script>
#   jQuery(document).ready(function($) {
#
#   $(window).on('load', function(){
#     $('#preloader').fadeOut('slow',function(){$(this).remove();});
#   });
#
#   });
# </script>
#
# <style type="text/css">
#   div#preloader { position: fixed;
#       left: 0;
#       top: 0;
#       z-index: 999;
#       width: 100%;
#       height: 100%;
#       overflow: visible;
#       background: #fff url('http://preloaders.net/preloaders/720/Moving%20line.gif') no-repeat center center;
#   }
#
# </style>
#
# <div id="preloader">
#
# </div>

# %% [raw]
# <script>
#   function code_toggle() {
#     if (code_shown){
#       $('div.input').hide('500');
#       $('#toggleButton').val('Show Code')
#     } else {
#       $('div.input').show('500');
#       $('#toggleButton').val('Hide Code')
#     }
#     code_shown = !code_shown
#   }
#
#   $( document ).ready(function(){
#     code_shown=false;
#     $('div.input').hide()
#   });
# </script>
# <form action="javascript:code_toggle()"><input type="submit" id="toggleButton" value="Show Code"></form>

# %% [markdown]
# <h1 style="text-align: center;" markdown="1"> CIFAR10 - Momentum and Dampening</h1>
# <h2 style="text-align: center;" markdown="1"> WideResnet - 28 - 10</h2>

# %%
import numpy as np
import pandas as pd
from bokeh.io import output_notebook
from bokeh.plotting import figure, show, output_file
from Outputs.jupyter_graphs import create_graphs, compare_graphs
from IPython.display import Markdown, display
from IPython.core.interactiveshell import InteractiveShell
import warnings
warnings.filterwarnings('ignore')
sim_num = [607, 307, 315]
plots, scores = compare_graphs(sim_nums=sim_num, linear=True)
output_notebook()
for sim in zip(sim_num,scores):
    display(Markdown('<h6> #Simulation {:1d} - Min Error {:.2f}% , Mean Error {:.2f}% , Val Error {:.2f}%<h6>'.format(sim[0],sim[1][0],sim[1][1],sim[1][2])))
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="d1f10130-a6cb-4fc3-ae24-bb62213a2de8">Loading BokehJS ...</span>
#     </div>
# <h6> #Simulation 607 - Min Error 3.88% , Mean Error 4.00% , Val Error 4.01%<h6>
# <h6> #Simulation 307 - Min Error 3.91% , Mean Error 4.00% , Val Error 4.01%<h6>
# <h6> #Simulation 315 - Min Error 3.68% , Mean Error 3.78% , Val Error 3.75%<h6>

# %%
print('Legend - (batchsize, #w, momentum, dampening, lr, #sim)')
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[1])
# Out:
# Legend - (batchsize, #w, momentum, dampening, lr, #sim)
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="6749efd9-670c-4fef-9e21-cb42380e612c"></div>
# </div>

# %%
show(plots[0])
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="390e4687-c4de-4232-bc95-6133a375c20e"></div>
# </div>

# %%
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[2])
# Out:
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="653bbc21-fc78-4497-a3cc-20e5bdd086b7"></div>
# </div>

# %%
print('607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum')
show(plots[3])
# Out:
# 607 - Baseline Momentum + Dampening, 315 - Baseline Momentum, 307 - Baseline No Momentum
# <div class="bk-root">
#     <div class="bk-plotdiv" id="aa24b1ad-c075-41b7-9bcf-6e16480d25c0"></div>
# </div>

# %% [raw]
# <script>
#   $(document).ready(function(){
#     $('div.prompt').hide();
#     $('div.back-to-top').hide();
#     $('nav#menubar').hide();
#     $('.breadcrumb').hide();
#     $('.hidden-print').hide();
#   });
# </script>
#
# <footer id="attribution" style="float:right; color:#999; background:#fff;">
# Niv Giladi - Technion
# </footer>
